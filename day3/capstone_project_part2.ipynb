# %%
import pandas as pd

# %%
df_news=pd.read_csv("Combined_News_DJIA.csv")
df_news['Date']=pd.to_datetime(df_news['Date'])

# %%
df_price=pd.read_csv("new_djprice.csv")
df_price.head()
# Out:
#          Date      Open      High       Low    Close*  Adj Close**  \
# 0  2008-07-07  11289.19  11399.11  11120.74  11231.96     11231.96
# 1  2008-07-08  11225.03  11391.13  11174.88  11384.21     11384.21
# 2  2008-07-09  11381.93  11418.24  11141.99  11147.44     11147.44
# 3  2008-07-10  11148.01  11270.30  11086.95  11229.02     11229.02
# 4  2008-07-11  11226.17  11241.07  10977.68  11100.54     11100.54
#
#         Volume  percentage  z-score
# 0  248240000.0         NaN      NaN
# 1  271500000.0    0.013555      NaN
# 2  227100000.0   -0.020798      NaN
# 3  248010000.0    0.007318      NaN
# 4  275010000.0   -0.011442      NaN

# %%
df_price['Date']=pd.to_datetime(df_price['Date'])
df_price
# Out:
#            Date      Open      High       Low    Close*  Adj Close**  \
# 0    2008-07-07  11289.19  11399.11  11120.74  11231.96     11231.96
# 1    2008-07-08  11225.03  11391.13  11174.88  11384.21     11384.21
# 2    2008-07-09  11381.93  11418.24  11141.99  11147.44     11147.44
# 3    2008-07-10  11148.01  11270.30  11086.95  11229.02     11229.02
# 4    2008-07-11  11226.17  11241.07  10977.68  11100.54     11100.54
# ...         ...       ...       ...       ...       ...          ...
# 3770 2023-06-28  33881.38  33903.76  33755.92  33852.66     33852.66
# 3771 2023-06-29  33854.57  34147.68  33828.63  34122.42     34122.42
# 3772 2023-06-30  34269.92  34467.35  34269.92  34407.60     34407.60
# 3773 2023-07-03  34369.78  34465.60  34286.54  34418.47     34418.47
# 3774 2023-07-05  34344.72  34376.11  34226.98  34288.64     34288.64
#
#            Volume  percentage   z-score
# 0     248240000.0         NaN       NaN
# 1     271500000.0    0.013555       NaN
# 2     227100000.0   -0.020798       NaN
# 3     248010000.0    0.007318       NaN
# 4     275010000.0   -0.011442       NaN
# ...           ...         ...       ...
# 3770  268050000.0   -0.002184  0.583472
# 3771  279940000.0    0.007969  1.244567
# 3772  351060000.0    0.008358  1.887133
# 3773  157590000.0    0.000316  1.840525
# 3774  274570000.0   -0.003772  1.485440
#
# [3775 rows x 9 columns]

# %%
df_master=df_price.merge(df_news, how='left', on='Date')

# %%
df_master
df_re_master=df_master.dropna()
df_re_master
len(df_re_master)/252
# Out:
# 7.773809523809524

# %%
# lets add any significant and then lets check the sentiment
# Out:
#            Date      Open      High       Low    Close*  Adj Close**  \
# 51   2008-09-17  11056.58  11057.31  10595.90  10609.66     10609.66
# 52   2008-09-18  10609.01  11076.44  10459.44  11019.69     11019.69
# 53   2008-09-19  11027.51  11483.05  11026.70  11388.44     11388.44
# 54   2008-09-22  11394.42  11394.58  10992.20  11015.69     11015.69
# 55   2008-09-23  11015.69  11143.21  10833.94  10854.17     10854.17
# ...         ...       ...       ...       ...       ...          ...
# 2008 2016-06-27  17355.21  17355.21  17063.08  17140.24     17140.24
# 2009 2016-06-28  17190.51  17409.72  17190.51  17409.72     17409.72
# 2010 2016-06-29  17456.02  17704.51  17456.02  17694.68     17694.68
# 2011 2016-06-30  17712.76  17930.61  17711.80  17929.99     17929.99
# 2012 2016-07-01  17924.24  18002.38  17916.91  17949.37     17949.37
#
#            Volume  percentage   z-score  Label  ...  \
# 51    463200000.0   -0.040633 -3.403907    0.0  ...
# 52    488060000.0    0.038647 -1.564634    1.0  ...
# 53    655110000.0    0.033463  0.011810    1.0  ...
# 54    213210000.0   -0.032731 -1.549244    0.0  ...
# 55    204480000.0   -0.014663 -2.108707    0.0  ...
# ...           ...         ...       ...    ...  ...
# 2008  138740000.0   -0.014971 -3.342046    0.0  ...
# 2009  112190000.0    0.015722 -1.833787    1.0  ...
# 2010  106380000.0    0.016368 -0.374812    1.0  ...
# 2011  133030000.0    0.013298  0.831005    1.0  ...
# 2012   82160000.0    0.001081  0.952191    1.0  ...
#
#                                                   Top16  \
# 51    b" Thaksin's brother-in-law is elected as Thai...
# 52    b'Iraqis kills 3 contractors, city Fallujah is...
# 53    b'America continues to lose world influence as...
# 54    b"All We are Saying is GIve Peace a Chance - U...
# 55    b'Sarkozy calls for those behind the market cr...
# ...                                                 ...
# 2008  German lawyers to probe Erdogan over alleged w...
# 2009  US, Canada and Mexico pledge 50% of power from...
# 2010  Escape Tunnel, Dug by Hand, Is Found at Holoca...
# 2011  Googles free wifi at Indian railway stations i...
# 2012  The United States has placed Myanmar, Uzbekist...
#
#                                                   Top17  \
# 51    b'1st anniversary of the beginning of the Saff...
# 52    b'CIA Chief Speaks of Trying to Provoke Terror...
# 53    b'Rice says U.S. will resist Russian moves aga...
# 54                  b'Dig pinpoints Stonehenge origins'
# 55    b"Russia engages in 'gangland' diplomacy as it...
# ...                                                 ...
# 2008  Boris Johnson says the UK will continue to "in...
# 2009  There is increasing evidence that Australia is...
# 2010  The land under Beijing is sinking by as much a...
# 2011  Mounting evidence suggests 'hobbits' were wipe...
# 2012  S&amp;P revises European Union credit rating t...
#
#                                                   Top18  \
# 51                    b'Russian stock market falls 17%'
# 52    b'German Authorities Wiretap Skype, Raid Homes...
# 53    b'14 men rob a coca cola factory - shoot out w...
# 54    b'Almost 13,000 Chinese children sickened by t...
# 55    b"EU patent office on strike: 'the organisatio...
# ...                                                 ...
# 2008  Richard Branson is calling on the UK governmen...
# 2009  Richard Branson, the founder of Virgin Group, ...
# 2010  Car bomb and Anti-Islamic attack on Mosque in ...
# 2011  The men who carried out Tuesday's terror attac...
# 2012  India gets $1 billion loan from World Bank for...
#
#                                                   Top19  \
# 51        b'Car bombs at U.S. embassy in Yemen kill 16'
# 52    b'In Yemen, a Planned Massacre of Americans Is...
# 53    b'South Ossetia information warfare, two sides...
# 54    b"Pakistan's rulers were supposed to be in Hot...
# 55           b'Mystery surrounds hijacked Iranian ship'
# ...                                                 ...
# 2008             Turkey 'sorry for downing Russian jet'
# 2009  37,000-yr-old skull from Borneo reveals surpri...
# 2010  Emaciated lions in Taiz Zoo are trapped in blo...
# 2011  Calls to suspend Saudi Arabia from UN Human Ri...
# 2012  U.S. sailors detained by Iran spoke too much u...
#
#                                                   Top20  \
# 51    b"CIA: Bin Laden doesn't oversee day-to-day al...
# 52    b'Livni sweeps Kadima race; Olmert pledges coo...
# 53    b'North Korea preparing to restart nuclear rea...
# 54    b'Turkey scared to admit Armenian genocide, sa...
# 55    b' U.S.-led wars behind Wall Street crisis: Ah...
# ...                                                 ...
# 2008  Edward Snowden lawyer vows new push for pardon...
# 2009  Palestinians stone Western Wall worshipers; po...
# 2010  Rupert Murdoch describes Brexit as 'wonderful'...
# 2011  More Than 100 Nobel Laureates Call Out Greenpe...
# 2012  Mass fish kill in Vietnam solved as Taiwan ste...
#
#                                                   Top21  \
# 51    b'WTF? Six Brazilian politicians legally chang...
# 52    b'Rising prices tip another 75 million towards...
# 53    b' Venezuela expels U.S. rights group for crit...
# 54    b"Change in dinner plans saved Pakistan's rule...
# 55        b'Pakistan blames US raids for hotel bombing'
# ...                                                 ...
# 2008  Brexit opinion poll reveals majority don't wan...
# 2009  Jean-Claude Juncker asks Farage: Why are you h...
# 2010       More than 40 killed in Yemen suicide attacks
# 2011  British pedophile sentenced to 85 years in US ...
# 2012  Philippines president Rodrigo Duterte urges pe...
#
#                                                   Top22  \
# 51    b'Tony Blair to appear on The Daily Show with ...
# 52    b"Sri Lanka's navy says it has fought a sea ba...
# 53    b'Chavez expells Human Rights Watch from Venez...
# 54    b'Pakistani troops fire on intruding U.S. chop...
# 55    b'Double Darwin Award? A couple having sex on ...
# ...                                                 ...
# 2008  Conservative MP Leave Campaigner: "The leave c...
# 2009  "Romanians for Remainians" offering a new home...
# 2010  Google Found Disastrous Symantec and Norton Vu...
# 2011  US permitted 1,200 offshore fracks in Gulf of ...
# 2012  Spain arrests three Pakistanis accused of prom...
#
#                                                   Top23  \
# 51      b'At least 100 rapes in Karachi,Pakistan a day'
# 52    b'official poverty rates of 51.8% in Gaza and ...
# 53           b'Euthanasia advocate takes her own life.'
# 54    b'Heads are starting to role in China as the t...
# 55    b'Tourists Taken Hostage in Egypt - Relocated ...
# ...                                                 ...
# 2008  Economists predict UK recession, further weake...
# 2009  Brexit: Gibraltar in talks with Scotland to st...
# 2010  Extremist violence on the rise in Germany: Dom...
# 2011  We will be swimming in ridicule - French beach...
# 2012  Venezuela, where anger over food shortages is ...
#
#                                                   Top24  \
# 51    b'US footage of attack that killed Pakistani s...
# 52    b'India deploys planes with Nuclear Capability...
# 53     b"The complete list of the world's billionaires"
# 54    b'Russian ambassador: Czechs selling security ...
# 55                 b'Bush, Ahmadinejad To Speak At UN '
# ...                                                 ...
# 2008  New EU 'superstate plan by France, Germany: Cr...
# 2009                   8 Suicide Bombers Strike Lebanon
# 2010  BBC News: Labour MPs pass Corbyn no-confidence...
# 2011  UEFA says no minutes of silence for Istanbul v...
# 2012  A Hindu temple worker has been killed by three...
#
#                                                   Top25
# 51    b"Potential HBOS- Lloyds merger 'bad news for ...
# 52    b'Tariq Ali: Has the U.S. Invasion of Pakistan...
# 53    b"Swaziland's HIV/AIDS treatment crisis goes c...
# 54    b"Merchant of Death appears in Thai court, no ...
# 55      b'Workers Allegedly Beat CEO To Death In India'
# ...                                                 ...
# 2008  Pakistani clerics declare transgender marriage...
# 2009  Mexico's security forces routinely use 'sexual...
# 2010  Tiny New Zealand town with 'too many jobs' lau...
# 2011  Law Enforcement Sources: Gun Used in Paris Ter...
# 2012  Ozone layer hole seems to be healing - US &amp...
#
# [1959 rows x 35 columns]

# %%
import openai

# %%
f = open("secret_key.env.txt", "r")
secret_key=f.read()
openai.api_key=secret_key

# %%
def openai_prompt(prompt):
    completion = openai.Completion.create(model="text-davinci-003", prompt=prompt)
    response=completion.choices[0].text
    return response

# %%
def extract_headline(row_data):
    """
    row_data=df_sig_news.iloc[row_index, :]
    """
    master_string=[str(i+1)+" : "+str(row_data[10:][i]) for i in range(0, len(row_data[10:]))]
    master_string="\n".join(master_string)
    return master_string

# %%
start_prompt="based on the below list of headline news, is there anything events related to Russia, geopolitical risk or significant oil price movement"
end_prompt="for the headlines that impact the market, make 3-5 words\
summary on the headline, seperate each factor by ':'. Reply 'NO' if there isnt any significant headline"

# %%
for i in range(0,df_re_master )
